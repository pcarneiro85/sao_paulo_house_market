# %%
import pandas as pd
url = 'https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv'

dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10) #sampling 10 rows of data
# Out:
#                           Rua                Bairro     Cidade  Metragem  \
# 9173                      NaN  Vila Conde do Pinhal  São Paulo        70
# 7858                Rua Iraci     Jardim Paulistano  São Paulo       200
# 6993       Rua das Fiandeiras          Vila Olímpia  São Paulo       309
# 1739                      NaN     Planalto Paulista  São Paulo       389
# 1656         Rua São Benedito           Santo Amaro  São Paulo       307
# 9126  Avenida Afrânio Peixoto               Butantã  São Paulo       313
# 3340                      NaN         Jardim Leonor  São Paulo       350
# 6032                      NaN         Jardim Europa  São Paulo       198
# 9165     Rua Manuel de Morais          Vila Mariana  São Paulo       170
# 6775    Rua Francisco Tapajós   Vila Santo Estéfano  São Paulo        82
#
#       Quartos  Banheiros  Vagas                                  Valor
# 9173        2          2      3                             R$ 365.000
# 7858        3          3      2                           R$ 2.500.000
# 6993        4          5      2                           R$ 3.900.000
# 1739        4          6      4                           R$ 2.500.000
# 1656        4          3      3                           R$ 2.000.000
# 9126        4          2     12  R$ 15.000\n                      /Mês
# 3340        3          4      5                           R$ 2.000.000
# 6032        4          3      5                           R$ 6.300.000
# 9165        3          3      3                           R$ 1.500.000
# 6775        3          2      1                             R$ 520.000

# %%
dados['Bairro'][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados['Metragem'].mean()
# Out:
# 442.30065947242207

# %% [markdown]
# ### Calculando a média da metragem das casas do bairro Vila Mariana

# %%
imoveis_vila_mariana = dados[dados['Bairro']=='Vila Mariana']
imoveis_vila_mariana.head()
# Out:
#                               Rua        Bairro     Cidade  Metragem  Quartos  \
# 100              Rua Pero Correia  Vila Mariana  São Paulo       250        3
# 120  Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250        3
# 155    Rua Professor João Marinho  Vila Mariana  São Paulo       170        3
# 160                           NaN  Vila Mariana  São Paulo       228        4
# 334        Rua Pero Correia, 892   Vila Mariana  São Paulo       350        6
#
#      Banheiros  Vagas         Valor
# 100          3      1  R$ 1.350.000
# 120          5      2  R$ 2.450.000
# 155          4      2  R$ 1.490.000
# 160          5      3  R$ 2.200.000
# 334          4     10  R$ 1.700.000

# %%
imoveis_vila_mariana['Metragem'].mean()
# Out:
# 233.6195652173913

# %%
n_imoveis_bairro = dados['Bairro'].value_counts()
n_imoveis_bairro
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro.head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Calcule a média da metragem por bairro

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
metragem_por_bairro = pd.DataFrame(dados.groupby('Bairro')['Metragem'].mean())
metragem_por_bairro
# Out:
#                      Metragem
# Bairro
# Aclimação          253.056818
# Alto da Boa Vista  418.875000
# Alto da Lapa       294.337209
# Alto da Mooca      270.050000
# Alto de Pinheiros  433.444988
# ...                       ...
# Vila Água Funda    152.200000
# Água Branca        191.000000
# Água Fria          165.416667
# Água Funda         139.000000
# Água Rasa          340.250000
#
# [701 rows x 1 columns]

# %%
metragem_por_bairro.describe()
# Out:
#            Metragem
# count    701.000000
# mean     285.448322
# std     1403.268009
# min       10.000000
# 25%      135.444444
# 50%      184.454545
# 75%      265.500000
# max    37000.000000

# %% [markdown]
# ## Agora iremos tratar os dados

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados['Valor'][0] #Devemos converter a coluna valor para float
# Out:
# 'R$ 7.000.000'

# %%
dados['Valor'][0].split() #O método split separa a string
# Out:
# ['R$', '7.000.000']

# %%
dados.sample(10)
# Out:
#                                        Rua             Bairro     Cidade  \
# 6742                                   NaN    Vila Tramontano  São Paulo
# 2887                                   NaN           Pacaembu  São Paulo
# 9656  Rua Dona Maria Cândida de Lima, 133    Vila Paulo Silas  São Paulo
# 9663                        Rua Luís Pinto        Vila Carrão  São Paulo
# 3061                                   NaN  Cidade Centenário  São Paulo
# 9338                                   NaN            Morumbi  São Paulo
# 8467                Rua Floresto Bandecchi            Jaguaré  São Paulo
# 2502                                   NaN     Retiro Morumbi  São Paulo
# 6696       Rua Doutor Francisco José Longo    Chácara Inglesa  São Paulo
# 9258          Rua João Batista Pereira, 0    Jardim Pinheiros  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 6742       388        3          7      8
# 2887       600        5          4      4
# 9656       320        5          3      4
# 9663       100        3          3      2
# 3061       180        2          3      2
# 9338       757        4          5      4
# 8467       150        3          2      4
# 2502      1356        5         12     26
# 6696       150        2          3      3
# 9258       140        3          4      3
#
#                                       Valor
# 6742                           R$ 4.900.000
# 2887                           R$ 3.500.000
# 9656                             R$ 520.000
# 9663                             R$ 590.000
# 3061                             R$ 600.000
# 9338                           R$ 3.900.000
# 8467                             R$ 650.000
# 2502  R$ 15.000\n                      /Mês
# 6696   R$ 4.500\n                      /Mês
# 9258                             R$ 750.000

# %% [markdown]
# Observe que na linha 6510 o valor contém mais erro. Somente o método split anterior não será suficiente para consertar isto.

# %%
dados['Valor'].str.split(expand = True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
dados['Valor'].str.split(expand = True)[0].unique()
# Out:
# array(['R$'], dtype=object)

# %%
dados['Valor'].str.split(expand = True)[1].unique()
# Out:
# array(['7.000.000', '3.700.000', '380.000', ..., '553.000', '951.000',
#        '2.200'], dtype=object)

# %%
dados['Valor'].str.split(expand = True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[['Moeda', 'Valor_anuncio', 'Tipo_anuncio']] = dados['Valor'].str.split(expand = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %% [markdown]
# Vamos eliminar os anúncios que referem-se a aluguéis

# %%
dados[dados['Tipo_anuncio'].isnull()]['Tipo_anuncio'].unique()
# Out:
# array([None], dtype=object)

# %%
dados_vendas = dados[dados['Tipo_anuncio'].isnull()]

# %%
dados_vendas.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
dados_vendas['Valor_anuncio'].str.replace('.','').astype(float) #Primeiramente devemos eliminar os pontos dos números. O python apenas aceita um ponto que representa o decimal. Aqui também temos pontos na casa de milhar.
# Out:
# /tmp/ipykernel_228/595629349.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_vendas['Valor_anuncio'].str.replace('.','').astype(float) #Primeiramente devemos eliminar os pontos dos números. O python apenas aceita um ponto que representa o decimal. Aqui também temos pontos na casa de milhar.
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas['Valor_anuncio_float'] = dados_vendas['Valor_anuncio'].str.replace('.','').astype(float)
# Out:
# /tmp/ipykernel_228/251354584.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_vendas['Valor_anuncio_float'] = dados_vendas['Valor_anuncio'].str.replace('.','').astype(float)
# /tmp/ipykernel_228/251354584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas['Valor_anuncio_float'] = dados_vendas['Valor_anuncio'].str.replace('.','').astype(float)

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rua                  6107 non-null   object
#  1   Bairro               9146 non-null   object
#  2   Cidade               9156 non-null   object
#  3   Metragem             9156 non-null   int64
#  4   Quartos              9156 non-null   int64
#  5   Banheiros            9156 non-null   int64
#  6   Vagas                9156 non-null   int64
#  7   Valor                9156 non-null   object
#  8   Moeda                9156 non-null   object
#  9   Valor_anuncio        9156 non-null   object
#  10  Tipo_anuncio         0 non-null      object
#  11  Valor_anuncio_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_vendas['Valor_anuncio_float'].plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dados_vendas.describe()
# Out:
#             Metragem      Quartos    Banheiros        Vagas  \
# count    9156.000000  9156.000000  9156.000000  9156.000000
# mean      434.416230     3.446811     3.797073     3.960135
# std      7856.422978     1.048944     1.967873     2.601022
# min        10.000000     1.000000     1.000000     1.000000
# 25%       168.000000     3.000000     2.000000     2.000000
# 50%       276.000000     3.000000     4.000000     4.000000
# 75%       450.000000     4.000000     5.000000     5.000000
# max    750000.000000    16.000000    40.000000    50.000000
#
#        Valor_anuncio_float
# count         9.156000e+03
# mean          3.052203e+06
# std           3.944208e+06
# min           1.300000e+04
# 25%           8.900000e+05
# 50%           1.800000e+06
# 75%           3.500000e+06
# max           6.500000e+07

# %%
pd.set_option('display.precision', 2) #diminui o número de casas decimais do display
dados_vendas.describe()
# Out:
#         Metragem  Quartos  Banheiros    Vagas  Valor_anuncio_float
# count    9156.00  9156.00    9156.00  9156.00             9.16e+03
# mean      434.42     3.45       3.80     3.96             3.05e+06
# std      7856.42     1.05       1.97     2.60             3.94e+06
# min        10.00     1.00       1.00     1.00             1.30e+04
# 25%       168.00     3.00       2.00     2.00             8.90e+05
# 50%       276.00     3.00       4.00     4.00             1.80e+06
# 75%       450.00     4.00       5.00     5.00             3.50e+06
# max    750000.00    16.00      40.00    50.00             6.50e+07

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x) #Converte valores científicos em numéricos.
dados_vendas.describe(include = 'all')
# Out:
#                       Rua             Bairro     Cidade  Metragem  Quartos  \
# count                6107               9146       9156   9156.00  9156.00
# unique               3006                697          1       NaN      NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo       NaN      NaN
# freq                   24                369       9156       NaN      NaN
# mean                  NaN                NaN        NaN    434.42     3.45
# std                   NaN                NaN        NaN   7856.42     1.05
# min                   NaN                NaN        NaN     10.00     1.00
# 25%                   NaN                NaN        NaN    168.00     3.00
# 50%                   NaN                NaN        NaN    276.00     3.00
# 75%                   NaN                NaN        NaN    450.00     4.00
# max                   NaN                NaN        NaN 750000.00    16.00
#
#         Banheiros   Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# count     9156.00 9156.00          9156  9156          9156            0
# unique        NaN     NaN           939     1           939            0
# top           NaN     NaN  R$ 2.500.000    R$     2.500.000          NaN
# freq          NaN     NaN           182  9156           182          NaN
# mean         3.80    3.96           NaN   NaN           NaN          NaN
# std          1.97    2.60           NaN   NaN           NaN          NaN
# min          1.00    1.00           NaN   NaN           NaN          NaN
# 25%          2.00    2.00           NaN   NaN           NaN          NaN
# 50%          4.00    4.00           NaN   NaN           NaN          NaN
# 75%          5.00    5.00           NaN   NaN           NaN          NaN
# max         40.00   50.00           NaN   NaN           NaN          NaN
#
#         Valor_anuncio_float
# count               9156.00
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean             3052202.96
# std              3944208.19
# min                13000.00
# 25%               890000.00
# 50%              1800000.00
# 75%              3500000.00
# max             65000000.00

# %%
dados_vendas[['Rua', 'Bairro', 'Cidade']].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00

# %% [markdown]
# ## Plotando alguns gráficos

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize = (10, 8))
ax = sns.histplot(data = dados_vendas, x = 'Valor_anuncio_float', kde = True)
ax.set_title('Histograma do Valor do Imóvel')
plt.xlim((-50, 10000000))

plt.show()

# %% [markdown]
# ## Qual o preço por metro quadrado por bairro?

# %%
dados_vendas.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None
#
#    Valor_anuncio_float
# 0           7000000.00
# 1           3700000.00
# 2            380000.00
# 3            685000.00
# 4            540000.00

# %%
dados_vendas['Valor_por_metro2'] = dados_vendas['Valor_anuncio_float'] / dados_vendas['Metragem']
# Out:
# /tmp/ipykernel_228/1126355736.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas['Valor_por_metro2'] = dados_vendas['Valor_anuncio_float'] / dados_vendas['Metragem']

# %%
dados_vendas.groupby('Bairro')['Valor_por_metro2'].describe()
# Out:
#                    count     mean     std     min     25%      50%      75%  \
# Bairro
# Aclimação          79.00  7656.17 3087.22 3333.33 6000.00  7272.73  8528.14
# Alto da Boa Vista   8.00  5849.57 1251.64 4352.33 4875.26  5831.93  6711.05
# Alto da Lapa       80.00  7606.73 2897.23 2123.89 5928.24  7402.60  8857.14
# Alto da Mooca      20.00  5691.74 2025.24 1987.58 4912.28  5801.28  6728.94
# Alto de Pinheiros 369.00 11269.98 3939.97 3495.44 8625.00 10703.12 13245.03
# ...                  ...      ...     ...     ...     ...      ...      ...
# Vila Água Funda     5.00  4467.13 1532.07 2700.00 3421.05  4111.11  5944.06
# Água Branca        12.00  7269.11 1671.02 5902.44 6249.57  6584.81  7961.09
# Água Fria          12.00  5841.10 1278.07 3805.73 4903.12  6076.92  6733.48
# Água Funda          2.00  3876.86  617.82 3440.00 3658.43  3876.86  4095.29
# Água Rasa           6.00  4509.61 1868.51 1832.84 4126.39  4138.89  4984.72
#
#                        max
# Bairro
# Aclimação         20000.00
# Alto da Boa Vista  7460.32
# Alto da Lapa      20543.48
# Alto da Mooca      9090.91
# Alto de Pinheiros 25714.29
# ...                    ...
# Vila Água Funda    6159.42
# Água Branca       11818.18
# Água Fria          7588.24
# Água Funda         4313.73
# Água Rasa          7558.14
#
# [697 rows x 8 columns]

# %%
preco_por_metro2 = dados_vendas.groupby('Bairro').median()
preco_por_metro2.head()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação            220.00     3.00       3.00   3.00           1500000.00
# Alto da Boa Vista    378.00     4.00       5.50   4.00           2275000.00
# Alto da Lapa         265.00     3.00       4.00   4.00           1750000.00
# Alto da Mooca        182.50     3.00       2.00   4.00           1222500.00
# Alto de Pinheiros    412.00     4.00       5.00   4.00           4100000.00
#
#                    Valor_por_metro2
# Bairro
# Aclimação                   7272.73
# Alto da Boa Vista           5831.93
# Alto da Lapa                7402.60
# Alto da Mooca               5801.28
# Alto de Pinheiros          10703.12

# %%
top10_bairros = dados_vendas['Bairro'].value_counts()[:10].index
top10_bairros
# Out:
# Index(['Alto de Pinheiros', 'Jardim Guedala', 'Jardim Paulista',
#        'Brooklin Paulista', 'Jardim Europa', 'Pacaembu', 'Vila Madalena',
#        'Cidade Jardim', 'Planalto Paulista', 'Jardim Leonor'],
#       dtype='object')

# %%
preco_por_metro2.reset_index(inplace= True)
preco_por_metro2.head()
# Out:
#               Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0          Aclimação    220.00     3.00       3.00   3.00
# 1  Alto da Boa Vista    378.00     4.00       5.50   4.00
# 2       Alto da Lapa    265.00     3.00       4.00   4.00
# 3      Alto da Mooca    182.50     3.00       2.00   4.00
# 4  Alto de Pinheiros    412.00     4.00       5.00   4.00
#
#    Valor_anuncio_float  Valor_por_metro2
# 0           1500000.00           7272.73
# 1           2275000.00           5831.93
# 2           1750000.00           7402.60
# 3           1222500.00           5801.28
# 4           4100000.00          10703.12

# %%
preco_por_metro2.query('Bairro in @top10_bairros') #Filtrando o banco de dados de acordo com a variável criada anteriormente
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 4    Alto de Pinheiros    412.00     4.00       5.00   4.00
# 19   Brooklin Paulista    268.00     3.00       4.00   3.50
# 57       Cidade Jardim    605.00     4.00       5.00   6.00
# 155      Jardim Europa    550.50     4.00       5.00   4.00
# 168     Jardim Guedala    595.00     4.00       6.00   6.00
# 187      Jardim Leonor    550.00     4.00       5.00   4.00
# 227    Jardim Paulista    450.00     4.00       5.00   4.00
# 338           Pacaembu    405.00     4.00       4.00   4.00
# 396  Planalto Paulista    285.00     3.00       4.00   4.00
# 564      Vila Madalena    305.00     4.00       4.00   3.00
#
#      Valor_anuncio_float  Valor_por_metro2
# 4             4100000.00          10703.12
# 19            1850000.00           6919.89
# 57            4800000.00           7907.74
# 155           9500000.00          19144.61
# 168           4200000.00           7362.50
# 187           3500000.00           6154.23
# 227           6000000.00          15315.26
# 338           3000000.00           8296.70
# 396           1695000.00           6091.96
# 564           2800000.00           8227.56

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x = 'Bairro', y = 'Valor_por_metro2', data = preco_por_metro2.query('Bairro in @top10_bairros'))
ax.tick_params(axis = 'x', rotation = 45)

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x = 'Bairro', y = 'Valor_por_metro2', data = dados_vendas.query('Bairro in @top10_bairros'))
ax.tick_params(axis = 'x', rotation = 45)

# %% [markdown]
# ## Linkando nosso banco de dados com o banco de dados do IBGE

# %%
url_ibge = 'https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv'

df_ibge = pd.read_csv(url_ibge, sep= ';')
df_ibge.head()
# Out:
#          Cod_setor  Cod_Grandes Regi�es Nome_Grande_Regiao  Cod_UF  \
# 0  355030801000001                    3     Regi�o Sudeste      35
# 1  355030801000002                    3     Regi�o Sudeste      35
# 2  355030801000003                    3     Regi�o Sudeste      35
# 3  355030801000004                    3     Regi�o Sudeste      35
# 4  355030801000005                    3     Regi�o Sudeste      35
#
#   Nome_da_UF   Cod_meso                Nome_da_meso  Cod_micro Nome_da_micro  \
# 0   S�o Paulo      3515  Metropolitana de S�o Paulo      35061     S�o Paulo
# 1   S�o Paulo      3515  Metropolitana de S�o Paulo      35061     S�o Paulo
# 2   S�o Paulo      3515  Metropolitana de S�o Paulo      35061     S�o Paulo
# 3   S�o Paulo      3515  Metropolitana de S�o Paulo      35061     S�o Paulo
# 4   S�o Paulo      3515  Metropolitana de S�o Paulo      35061     S�o Paulo
#
#    Cod_RM  ...  V004     V005        V006     V007        V008     V009  \
# 0      20  ...  2,32  2091,32  8532451,78  2164,55  8673276,78  1227,41
# 1      20  ...  2,09  1650,09  3983441,31  1717,44  4030519,99  1045,78
# 2      20  ...  3,08  1280,43  5474593,06  2349,53  7553913,02   902,97
# 3      20  ...  2,26  1119,59   3572955,1  1859,13   4567289,5   869,09
# 4      20  ...  2,35   1416,9  2240207,58  1581,66  2240109,39   917,71
#
#          V010     V011        V012  Unnamed: 33
# 0  4285771,99  1713,75  5152087,86          NaN
# 1  2572133,32  1468,08  2991546,94          NaN
# 2  2735492,52  1786,79  3837674,74          NaN
# 3  2122409,02  1567,41  2735383,24          NaN
# 4  1570047,75  1356,35  1725877,85          NaN
#
# [5 rows x 34 columns]

# %%
df_ibge['V012'].unique()
# Out:
# array(['5152087,86', '2991546,94', '3837674,74', ..., '181129,99',
#        '550319,43', '98771,74'], dtype=object)

# %%
df_ibge.drop(columns=['Cod_Grandes Regi�es', 'Nome_Grande_Regiao',	'Cod_UF','Nome_da_UF ', 'Cod_meso', 'Nome_da_meso', 'Cod_micro', 'Nome_da_micro', 'Cod_RM', 'Nome_da_RM','Cod_municipio','Nome_do_municipio', 'Cod_bairro', 'Nome_do_bairro','Unnamed: 33'], inplace= True)

# %%
df_ibge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18363 entries, 0 to 18362
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cod_setor            18363 non-null  int64
#  1   Cod_distrito         18363 non-null  int64
#  2   Nome_do_distrito     18363 non-null  object
#  3   Cod_subdistrito      18363 non-null  int64
#  4   Nome_do_subdistrito  18363 non-null  object
#  5   Situacao_setor       18363 non-null  int64
#  6   Tipo_setor           18363 non-null  int64
#  7   V001                 18333 non-null  float64
#  8   V002                 18333 non-null  float64
#  9   V003                 18333 non-null  object
#  10  V004                 18333 non-null  object
#  11  V005                 18333 non-null  object
#  12  V006                 18333 non-null  object
#  13  V007                 18324 non-null  object
#  14  V008                 18324 non-null  object
#  15  V009                 18363 non-null  object
#  16  V010                 18363 non-null  object
#  17  V011                 18352 non-null  object
#  18  V012                 18352 non-null  object
# dtypes: float64(2), int64(5), object(12)
# memory usage: 2.7+ MB

# %%
df_ibge.sample(20)
# Out:
#              Cod_setor  Cod_distrito   Nome_do_distrito  Cod_subdistrito  \
# 4182   355030825000145     355030825  CIDADE TIRADENTES      35503082500
# 4627   355030827000113     355030827            CURSINO      35503082700
# 4278   355030825000241     355030825  CIDADE TIRADENTES      35503082500
# 10522  355030855000032     355030855        PARELHEIROS      35503085500
# 16131  355030884000059     355030884        VILA CURU��      35503088400
# 10034  355030851000027     355030851           MANDAQUI      35503085100
# 13596  355030870000208     355030870            SANTANA      35503087000
# 3802   355030823000182     355030823       CIDADE DUTRA      35503082300
# 15426  355030881000050     355030881           TREMEMB�      35503088100
# 15860  355030883000008     355030883       VILA ANDRADE      35503088300
# 7434   355030838000181     355030838          JABAQUARA      35503083800
# 6855   355030836000236     355030836     ITAIM PAULISTA      35503083600
# 408    355030804000095     355030804         ARICANDUVA      35503080400
# 15566  355030881000193     355030881           TREMEMB�      35503088100
# 16439  355030886000020     355030886     VILA GUILHERME      35503088600
# 7971   355030842000023     355030842            JARAGU�      35503084200
# 7808   355030839000149     355030839             JA�AN�      35503083900
# 5666   355030830000642     355030830             GRAJA�      35503083000
# 2556   355030818000178     355030818           CANGAIBA      35503081800
# 16119  355030884000047     355030884        VILA CURU��      35503088400
#
#       Nome_do_subdistrito  Situacao_setor  Tipo_setor   V001    V002  V003  \
# 4182    CIDADE TIRADENTES               1           0 225.00  746.00  3,32
# 4627              CURSINO               1           0 251.00  728.00   2,9
# 4278    CIDADE TIRADENTES               1           1 235.00 1057.00   4,5
# 10522         PARELHEIROS               1           0 281.00 1022.00  3,64
# 16131         VILA CURU��               1           0 189.00  594.00  3,14
# 10034            MANDAQUI               1           0 278.00  854.00  3,07
# 13596             SANTANA               1           0 264.00  807.00  3,06
# 3802         CIDADE DUTRA               1           0 272.00  816.00     3
# 15426            TREMEMB�               1           0 392.00 1180.00  3,01
# 15860        VILA ANDRADE               1           1 539.00 1812.00  3,36
# 7434            JABAQUARA               1           0 182.00  538.00  2,96
# 6855       ITAIM PAULISTA               1           0 251.00  822.00  3,27
# 408            ARICANDUVA               1           0 212.00  692.00  3,26
# 15566            TREMEMB�               1           0 415.00 1543.00  3,72
# 16439      VILA GUILHERME               1           0 292.00  953.00  3,26
# 7971              JARAGU�               1           0 280.00  791.00  2,83
# 7808               JA�AN�               1           1 178.00  676.00   3,8
# 5666               GRAJA�               1           1  85.00  250.00  2,94
# 2556             CANGAIBA               1           0  95.00  293.00  3,08
# 16119         VILA CURU��               1           0 269.00  932.00  3,46
#
#         V004     V005         V006     V007         V008     V009        V010  \
# 4182    2,87  1025,52    719627,51  1171,28     650834,2   629,63   531239,76
# 4627    2,05  2632,56   6681570,48   2811,8   6632295,66   1682,9   4571957,2
# 4278   10,56   155,96     87583,66   538,97     96375,31   209,15    82852,22
# 10522   3,15   907,38    682143,23   1007,8     656330,2   517,21   499169,28
# 16131   2,42  1016,32   2876778,34  1444,25   3474517,29   659,91  1448330,02
# 10034   1,79  2266,05   8406932,81  3662,57   8473486,71  1658,15  7812808,17
# 13596   2,49  3009,76  23537951,89  3324,59  24959354,69  1761,48  16431386,3
# 3802    1,64  1594,99   2285221,24  1919,63   2126458,33   1053,3  1697790,19
# 15426   2,08   1581,2   2695877,75  1670,71   2698951,15  1022,82  1769987,27
# 15860   2,88   749,03    711807,48   873,87    721370,05      475   398477,27
# 7434    1,68  2382,19  10969461,84  2890,39  11846560,16  1932,07  7270872,62
# 6855    1,95    769,2     614897,8     1116    504462,47   676,54  1021861,96
# 408     2,45  1110,92   1012522,96     1214    981173,17   707,91   716241,45
# 15566   2,93   811,28    467145,68   956,48    411716,02   532,32   380691,34
# 16439   2,34  1814,82   8668447,42  2344,81   9962935,42  1271,39  4468599,04
# 7971    1,79  1803,53   2345099,57  1891,34   2293003,09  1188,38  1851351,67
# 7808    2,13   762,02     69114,53   770,68     63192,68   474,41      136983
# 5666     1,6   500,59    264091,32   834,31    159673,02   423,74   237076,91
# 2556    2,38  1488,29   2134443,55  1570,98   2123003,42   854,31  1341178,25
# 16119   2,49   981,19    666306,86     1060     636165,4   591,12   476776,26
#
#           V011         V012
# 4182    999,16    473657,31
# 4627   2295,49   4830524,16
# 4278    524,53     42230,72
# 10522   891,23    526859,45
# 16131  1194,67   1984966,44
# 10034  3006,12  10117268,67
# 13596  2602,52  22099507,16
# 3802   1665,74   1664732,92
# 15426  1433,84   1892085,65
# 15860   775,25     417609,3
# 7434   2458,56   7959504,15
# 6855   1103,15   1196025,04
# 408    1078,81    691314,57
# 15566   883,45     321520,8
# 16439  1860,73   5445073,72
# 7971   1580,04   1842655,38
# 7808    691,09     49591,39
# 5666     797,2    147539,98
# 2556   1307,52   1460814,51
# 16119   933,98    433003,45

# %%
(df_ibge['Nome_do_distrito'] == 'Jardim Guedala').sum()
# Out:
# 0
